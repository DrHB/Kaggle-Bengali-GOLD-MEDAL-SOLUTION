# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import os 
os.chdir('..')
import fastai
from fastai.vision import *
from fastai.callbacks import SaveModelCallback
from fastai.callbacks import TrackerCallback
from fastai.callbacks import CSVLogger
from fastai.data_block import _maybe_squeeze
from fastai.callbacks import *
from utils.mxresnet import *
from utils.ranger import *
from sklearn.model_selection import StratifiedKFold, KFold
from joblib import load, dump
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold
from efficientnet_pytorch import EfficientNet
import pretrainedmodels
#from utils.augment import *

# %%
class MishFunction(torch.autograd.Function):
    @staticmethod
    def forward(ctx, x):
        ctx.save_for_backward(x)
        return x * torch.tanh(F.softplus(x))   # x * tanh(ln(1 + exp(x)))

    @staticmethod
    def backward(ctx, grad_output):
        x = ctx.saved_variables[0]
        sigmoid = torch.sigmoid(x)
        tanh_sp = torch.tanh(F.softplus(x)) 
        return grad_output * (tanh_sp + x * sigmoid * (1 - tanh_sp * tanh_sp))

class Mish(nn.Module):
    def forward(self, x):
        return MishFunction.apply(x)

def to_Mish(model):
    for child_name, child in model.named_children():
        if isinstance(child, nn.ReLU):
            setattr(model, child_name, Mish())
        else:
            to_Mish(child)

# %%
FOLD = 0
NAME = 'EXP_60'
SUFFIX =f'RES_100_EPOCH_{FOLD}'
PATH = Path('../../../bengaliai')
SZ = 224
BS = 256
NFOLDS = 5 #keep the same split as the initial dataset
SEED = 2019
TRAIN_IMG = PATH/'img_trn_224'
LABELS = PATH/'train.csv'

os.chdir(NAME)

# %%
def strt_split(x, y, n_folds=5, random_seed = 42, path=Path('')):  
    try: 
        val_name = load('val_idx.joblib')
    except:
        skf = KFold(n_splits=n_folds, shuffle=True, random_state=random_seed)
        val_name = [(val_idx, trn_idx) for trn_idx, val_idx in skf.split(x, y)]
        dump(val_name,'val_idx.joblib')
    return val_name

def multi_strt_split(x, y, n_folds=5, random_seed = 42, path=Path('')):  
    try: 
        val_name = load('val_idx.joblib')
    except:
        skf = MultilabelStratifiedKFold(n_splits=n_folds, shuffle=True, random_state=random_seed)
        val_name = [(val_idx, trn_idx) for trn_idx, val_idx in skf.split(x, y)]
        dump(val_name,'val_idx.joblib')
    return val_name

# %%
df = pd.read_csv(str(LABELS))
nunique = list(df.nunique())[1:-1]

# %%
val_idx = multi_strt_split(df['image_id'], df[df.columns[1:-1]].get_values())[FOLD]
# Out:
# /home/bukharih/.conda/envs/hb/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.values' or 'np.asarray(..)' instead.
#   """Entry point for launching an IPython kernel.

# %%
#imagenet_stats
data = (ImageList.from_df(df, path='', folder=TRAIN_IMG, suffix='.png', 
        cols='image_id', convert_mode='L')
        .split_by_idxs(valid_idx=val_idx[0], train_idx=val_idx[1])
        .label_from_df(cols=['grapheme_root'])
        .transform(get_transforms(do_flip=False,max_warp=0.2, max_zoom=0.95, max_rotate=20, xtra_tfms=[cutout(n_holes=(5, 25), length=(10, 30), p=.5), squish(scale=0.66, p=0.3)]), size=SZ, padding_mode='zeros')
        .databunch(bs=BS)).normalize(([0.0786], [0.2130]))

data.show_batch()

# %%
stats_ = data.stats
stats_
# Out:
# ([0.0786], [0.213])

# %%
#from fastai_extensions import *

# %%
class Metric_idx(Callback):
    def __init__(self, average='macro'):
        super().__init__()
        self.n_classes = 0
        self.average = average
        self.cm = None
        self.eps = 1e-9
        
    def on_epoch_begin(self, **kwargs):
        self.tp = 0
        self.fp = 0
        self.cm = None
    
    def on_batch_end(self, last_output:Tensor, last_target:Tensor, **kwargs):
        last_output = last_output
        last_target = last_target
        preds = last_output.argmax(-1).view(-1).cpu()
        targs = last_target.long().cpu()
        
        if self.n_classes == 0:
            self.n_classes = last_output.shape[-1]
            self.x = torch.arange(0, self.n_classes)
        cm = ((preds==self.x[:, None]) & (targs==self.x[:, None, None])) \
          .sum(dim=2, dtype=torch.float32)
        if self.cm is None: self.cm =  cm
        else:               self.cm += cm

    def _weights(self, avg:str):
        if self.n_classes != 2 and avg == "binary":
            avg = self.average = "macro"
            warn("average=`binary` was selected for a non binary case. \
                 Value for average has now been set to `macro` instead.")
        if avg == "binary":
            if self.pos_label not in (0, 1):
                self.pos_label = 1
                warn("Invalid value for pos_label. It has now been set to 1.")
            if self.pos_label == 1: return Tensor([0,1])
            else: return Tensor([1,0])
        elif avg == "micro": return self.cm.sum(dim=0) / self.cm.sum()
        elif avg == "macro": return torch.ones((self.n_classes,)) / self.n_classes
        elif avg == "weighted": return self.cm.sum(dim=1) / self.cm.sum()
        
    def _recall(self):
        rec = torch.diag(self.cm) / (self.cm.sum(dim=1) + self.eps)
        if self.average is None: return rec
        else:
            if self.average == "micro": weights = self._weights(avg="weighted")
            else: weights = self._weights(avg=self.average)
            return (rec * weights).sum()
    
    def on_epoch_end(self, last_metrics, **kwargs): 
        return add_metrics(last_metrics, self._recall())
    
Metric_grapheme = partial(Metric_idx)

# %%
arch = pretrainedmodels.resnet50(num_classes=1000)
arch = list(arch.children())[:-1]
w = arch[0].weight
arch[0] = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)
arch[0].weight = nn.Parameter(torch.mean(w, dim=1, keepdim=True))
arch.append(Flatten())
arch.append(nn.Linear(2048, data.c))
arch = nn.Sequential(*arch)

# %%
to_Mish(arch)

# %%
learn = Learner(data, arch, loss_func=LabelSmoothingCrossEntropy(), opt_func = Over9000,
        metrics=[Metric_grapheme()])
learn.mixup()
learn.model = nn.DataParallel(learn.model)
learn.unfreeze()

lr = 34e-3/3
#learn.lr_find()

# %%
lr = 34e-3/3
learn.recorder.plot(skip_end=10)
plt.axvline(lr)

# %%
learn.unfreeze()
learn.fit_one_cycle(100, lr, wd=1e-2,  pct_start=0.0,  div_factor=100,
                    callbacks = [SaveModelCallback(learn, every='improvement', monitor='metric_idx', name = f'{NAME}_{SUFFIX}_{FOLD}')])
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='99' class='' max='100', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       99.00% [99/100 10:45:58<06:31]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>metric_idx</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.432829</td>
#       <td>1.559667</td>
#       <td>0.734749</td>
#       <td>06:38</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.181008</td>
#       <td>1.164642</td>
#       <td>0.892068</td>
#       <td>06:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.044416</td>
#       <td>1.205304</td>
#       <td>0.892521</td>
#       <td>06:31</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.970905</td>
#       <td>1.078739</td>
#       <td>0.917788</td>
#       <td>06:31</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.914447</td>
#       <td>1.150265</td>
#       <td>0.897732</td>
#       <td>06:30</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.860154</td>
#       <td>1.047427</td>
#       <td>0.926095</td>
#       <td>06:31</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1
td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>1.389299</td>
#       <td>0.987140</td>
#       <td>0.950185</td>
#       <td>06:30</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>1.383534</td>
#       <td>0.960165</td>
#       <td>0.954094</td>
#       <td>06:29</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>1.384598</td>
#       <td>0.976992</td>
#       <td>0.952933</td>
#       <td>06:29</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>1.378400</td>
#       <td>0.956992</td>
#       <td>0.953891</td>
#       <td>06:30</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>1.367752</td>
#       <td>0.979783</td>
#       <td>0.952215</td>
#       <td>06:31</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>1.366518</td>
#       <td>0.960389</td>
#       <td>0.953021</td>
#       <td>06:31</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>1.363400</td>
#       <td>0.971640</td>
#       <td>0.951727</td>
#       <td>06:31</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>1.356323</td>
#       <td>0.957138</td>
#       <td>0.954239</td>
#       <td>06:31</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.348442</td>
#       <td>0.965759</td>
#       <td>0.951823</td>
#       <td>06:31</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>1.349205</td>
#       <td>0.954549</td>
#       <td>0.952227</td>
#       <td>06:30</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>1.336544</td>
#       <td>0.965281</td>
#       <td>0.952755</td>
#       <td>06:31</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>1.337585</td>
#       <td>0.956306</td>
#       <td>0.952554</td>
#       <td>06:31</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>1.336287</td>
#       <td>0.965625</td>
#       <td>
# /home/bukharih/.conda/envs/hb/lib/python3.7/site-packages/ipykernel_launcher.py:9: DeprecationWarning: 'saved_variables' is deprecated; use 'saved_tensors'
#   if __name__ == '__main__':
# Better model found at epoch 0 with metric_idx value: 0.7347485423088074.
# Better model found at epoch 1 with metric_idx value: 0.8920676112174988.
# Better model found at epoch 2 with metric_idx value: 0.892521321773529.
# Better model found at epoch 3 with metric_idx value: 0.9177883267402649.
# Better model found at epoch 5 with metric_idx value: 0.9260947108268738.
# Better model found at epoch 7 with metric_idx value: 0.9342310428619385.
# Better model found at epoch 9 with metric_idx value: 0.9380979537963867.
# Better model found at epoch 11 with metric_idx value: 0.9432851672172546.
# Better model found at epoch 15 with metric_idx value: 0.943717896938324.
# Better model found at epoch 16 with metric_idx value: 0.945225715637207.
# Better model found at epoch 17 with metric_idx value: 0.9459671974182129.
# Better model found at epoch 19 with metric_idx value: 0.9486111998558044.
# Better model found at epoch 25 with metric_idx value: 0.948707640171051.
# Better model found at epoch 30 with metric_idx value: 0.9488780498504639.
# Better model found at epoch 31 with metric_idx value: 0.9501887559890747.
# Better model found at epoch 33 with metric_idx value: 0.9503284692764282.
# Better model found at epoch 35 with metric_idx value: 0.9518997073173523.
# Better model found at epoch 37 with metric_idx value: 0.9539499282836914.
# Better model found at epoch 43 with metric_idx value: 0.9540936946868896.
# Better model found at epoch 49 with metric_idx value: 0.9542392492294312.
# Better model found at epoch 54 with metric_idx value: 0.9546380043029785.
# Better model found at epoch 55 with metric_idx value: 0.954840362071991.
# Better model found at epoch 60 with metric_idx value: 0.9550821781158447.
# Better model found at epoch 62 with metric_idx value: 0.9559909105300903.
# Better model found at epoch 63 with metric_idx value: 0.9563100934028625.
# Better model found at epoch 67 with metric_idx value: 0.9579334855079651.
# Better model found at epoch 75 with metric_idx value: 0.9579526782035828.
# Better model found at epoch 76 with metric_idx value: 0.958403468132019.
# Better model found at epoch 87 with metric_idx value: 0.9588668942451477.
# Better model found at epoch 91 with metric_idx value: 0.9589356780052185.
# Better model found at epoch 92 with metric_idx value: 0.9590567946434021.

# %%
# !sudo shutdown
