# %%
import numpy as np
import pandas as pd
from openTSNE import TSNE
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# !ls
# Out:
# adap_layer_pred.npy			   models
# EXP_80_ATTN.ipynb			   tSNE_Extrction.ipynb
# EXP_80_ATTN-R2.ipynb			   tSNE.ipynb
# EXP_80_RESNEXT101_SIMPLE.ipynb		   val_idx.joblib
# EXP_80_RESNEXT101_SIMPLE_tSNE-Copy1.ipynb  val_resuls.csv

# %%
data = np.load('adap_layer_pred.npy')
df = pd.read_csv('val_resuls.csv')

# %%
embedding = TSNE(n_jobs=-1, perplexity=30, learning_rate=100, n_iter=5000).fit(data)

# %%
fig, axes = plt.subplots(figsize = (10, 10))
axes.scatter(embedding[:, 0], embedding[:, 1], alpha =0.01, c=df['vowel_diacritic'])

# %%
data.shape
# Out:
# (40168, 4096)

# %%
embedding.shape
# Out:
# (40168, 2)

# %%
embedding[:, 0].shape
